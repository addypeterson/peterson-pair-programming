# %%
import pair_programming
result = pair_programming.feetinch2meters(0,12)
print(result)
# Looks good!
# Out:
# 0.30479983540808886

# %%
result = pair_programming.feetinch2meters(3,10)
print(result)
# Looks good!
# Out:
# 1.1683993690643406
